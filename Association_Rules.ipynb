# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("Online retail.xlsx",header=None)

# %%
df
# Out:
#                                                       0
# 0     shrimp,almonds,avocado,vegetables mix,green gr...
# 1                                burgers,meatballs,eggs
# 2                                               chutney
# 3                                        turkey,avocado
# 4     mineral water,milk,energy bar,whole wheat rice...
# ...                                                 ...
# 7496                      butter,light mayo,fresh bread
# 7497  burgers,frozen vegetables,eggs,french fries,ma...
# 7498                                            chicken
# 7499                                 escalope,green tea
# 7500    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7501 rows x 1 columns]

# %%
df[0].value_counts()
# Out:
# cookies                                                                                                                                                                     223
# french fries                                                                                                                                                                132
# escalope                                                                                                                                                                    101
# mineral water                                                                                                                                                                93
# eggs                                                                                                                                                                         90
# ...

# %%
df[0].value_counts().head(40)
# Out:
# cookies                   223
# french fries              132
# escalope                  101
# mineral water              93
# eggs                       90
# chocolate                  73
# green tea                  72
# spaghetti                  52
# champagne                  45
# low fat yogurt             45
# pancakes                   39
# milk                       33
# cake                       29
# muffins                    27
# yogurt cake                25
# olive oil                  23
# candy bars                 23
# energy bar                 22
# grated cheese              21
# herb & pepper              21
# ground beef                21
# eggs,french fries          21
# cake,french fries          20
# burgers                    20
# frozen smoothie            20
# hot dogs                   20
# tomatoes                   19
# frozen vegetables          19
# whole wheat rice           18
# chocolate,french fries     18
# brownies                   18
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
color= plt.cm.rainbow(np.linspace(0,1,40)) 
df[0].value_counts().head(40).plot.bar(figsize=(13,8),color=color)
# Out:
# <AxesSubplot:>

# %%
transactions = []
for i in range(len(df)):
    transactions.append(str(df.values[i, 0]).split(','))  # Split by commas to separate items

# %%
transactions
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
# ...

# %%
print(transactions[:5])
# Out:
# [['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil'], ['burgers', 'meatballs', 'eggs'], ['chutney'], ['turkey', 'avocado'], ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea']]

# %%
len(transactions)
# Out:
# 7501

# %%
items1= [ items for trans in transactions for items in trans]

# %%
items2=list(set(items1))

# %%
print(list(items2))
# Out:
# ['energy bar', 'clothes accessories', 'zucchini', 'muffins', 'shrimp', 'gums', 'ketchup', 'light cream', 'honey', 'mineral water', ' asparagus', 'hot dogs', 'tea', 'whole wheat pasta', 'protein bar', 'chili', 'mashed potato', 'water spray', 'tomato sauce', 'rice', 'pancakes', 'escalope', 'shampoo', 'milk', 'mayonnaise', 'green grapes', 'burger sauce', 'yogurt cake', 'yams', 'oil', 'carrots', 'salmon', 'flax seed', 'light mayo', 'low fat yogurt', 'salt', 'green beans', 'strong cheese', 'cake', 'herb & pepper', 'napkins', 'chocolate', 'toothpaste', 'frozen vegetables', 'brownies', 'gluten free bar', 'mint', 'fresh bread', 'french fries', 'candy bars', 'bramble', 'chocolate bread', 'extra dark chocolate', 'vegetables mix', 'chutney', 'spaghetti', 'cookies', 'asparagus', 'pickles', 'eggplant', 'mint green tea', 'french wine', 'eggs', 'spinach', 'fromage blanc', 'dessert wine', 'bacon', 'magazines', 'mushroom cream sauce', 'avocado', 'whole weat flour', 'ground beef', 'sandwich', 'frozen 
# ...

# %%
len(items2)
# Out:
# 120

# %%
if 'nan' in items2:items2.remove('nan')
print(list(items2))
# Out:
# ['energy bar', 'clothes accessories', 'zucchini', 'muffins', 'shrimp', 'gums', 'ketchup', 'light cream', 'honey', 'mineral water', ' asparagus', 'hot dogs', 'tea', 'whole wheat pasta', 'protein bar', 'chili', 'mashed potato', 'water spray', 'tomato sauce', 'rice', 'pancakes', 'escalope', 'shampoo', 'milk', 'mayonnaise', 'green grapes', 'burger sauce', 'yogurt cake', 'yams', 'oil', 'carrots', 'salmon', 'flax seed', 'light mayo', 'low fat yogurt', 'salt', 'green beans', 'strong cheese', 'cake', 'herb & pepper', 'napkins', 'chocolate', 'toothpaste', 'frozen vegetables', 'brownies', 'gluten free bar', 'mint', 'fresh bread', 'french fries', 'candy bars', 'bramble', 'chocolate bread', 'extra dark chocolate', 'vegetables mix', 'chutney', 'spaghetti', 'cookies', 'asparagus', 'pickles', 'eggplant', 'mint green tea', 'french wine', 'eggs', 'spinach', 'fromage blanc', 'dessert wine', 'bacon', 'magazines', 'mushroom cream sauce', 'avocado', 'whole weat flour', 'ground beef', 'sandwich', 'frozen 
# ...

# %%
len(items2)
# Out:
# 120

# %%
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
encoder= TransactionEncoder().fit(transactions)

# %%
one_hot=encoder.transform(transactions)

# %%
one_hot
# Out:
# array([[False,  True,  True, ...,  True, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False]])

# %%
one_hot.shape
# Out:
# (7501, 120)

# %%
df1=pd.DataFrame(one_hot,columns=encoder.columns_)

# %%
df1
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
df1.shape
# Out:
# (7501, 120)

# %% [markdown]
# # Apriori

# %%
frequent_itemsets=apriori(df1,min_support=0.05,use_colnames=True)

# %%
frequent_itemsets
# Out:
#      support                    itemsets
# 0   0.087188                   (burgers)
# 1   0.081056                      (cake)
# 2   0.059992                   (chicken)
# 3   0.163845                 (chocolate)
# 4   0.080389                   (cookies)
# 5   0.051060               (cooking oil)
# 6   0.179709                      (eggs)
# 7   0.079323                  (escalope)
# 8   0.170911              (french fries)
# 9   0.063325           (frozen smoothie)
# 10  0.095321         (frozen vegetables)
# 11  0.052393             (grated cheese)
# 12  0.132116                 (green tea)
# 13  0.098254               (ground beef)
# 14  0.076523            (low fat yogurt)
# 15  0.129583                      (milk)
# 16  0.238368             (mineral water)
# 17  0.065858                 (olive oil)
# 18  0.095054                  (pancakes)
# 19  0.071457                    (shrimp)
# 20  0.050527                      (soup)
# 21  0.174110                 (spaghetti)
# ...

# %% [markdown]
# # Association rules

# %%
rules=association_rules(frequent_itemsets,metric='confidence',min_threshold=0.05)

# %%
rules
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0      (chocolate)  (mineral water)            0.163845            0.238368
# 1  (mineral water)      (chocolate)            0.238368            0.163845
# 2           (eggs)  (mineral water)            0.179709            0.238368
# 3  (mineral water)           (eggs)            0.238368            0.179709
# 4      (spaghetti)  (mineral water)            0.174110            0.238368
# 5  (mineral water)      (spaghetti)            0.238368            0.174110
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0  0.052660    0.321400  1.348332  0.013604    1.122357       0.308965
# 1  0.052660    0.220917  1.348332  0.013604    1.073256       0.339197
# 2  0.050927    0.283383  1.188845  0.008090    1.062815       0.193648
# 3  0.050927    0.213647  1.188845  0.008090    1.043158       0.208562
# 4  0.059725    0.343032  1.439085  0.018223    1.159314       0.369437
# ...

# %% [markdown]
# # Analysis and Interpretation:

# %%
# support
#(spaghetti) >(mineral water) with high support means that a significant portion of customers are purchasing both together.

# %%
# Lift gives an idea of the strength of the relationship between products compared to random chance.
# (spaghetti)>(mineral water) with lift 1.43 .5 means that chocolate and wine are bought together 1.43 times more often than would be expected if the purchases were independent.

# %%
# confidence
# (spaghetti)>(mineral water) with high confidence of 0.34 means that 30% of the transactions that have spaghetti also have mineral water.

# %% [markdown]
# # Interview Questions

# %%
# 1. What is Lift and Why is it Important in Association Rules?

# %%
 # Lift measures the strength of the association between two items, compared to how often the items would occur together by chance.
#A lift greater than 1 means that A and B are more likely to appear together than by chance (positive association).
# Lift helps identify strong associations between items that are not obvious and can guide marketing strategies or store placement.

# %%
# 2. What is Support and Confidence? How Do You Calculate Them?

# %%
# support:he proportion of transactions that contain a particular item or itemset.
# support(A)=(Number of transactions containing A)/(Total number of transactions)

# %%
# confidence:The likelihood that item B is purchased when item A is purchased.
# Confidence(A→B)= Support(A∩B)/Support(A)

# %%
# 3. What Are Some Limitations or Challenges of Association Rules Mining?

# %%
# Large Output: Mining can produce too many rules if the support and confidence thresholds are not set properly, making it hard to identify useful patterns.
#Interpretability:Rules with low support may be difficult to interpret because they are based on rare events that may not generalize well.
#Overfitting:High confidence rules may appear reliable but might only apply to specific data subsets, leading to overfitting and poor generalization.
